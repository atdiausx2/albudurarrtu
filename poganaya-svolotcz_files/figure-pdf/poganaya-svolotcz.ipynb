# %% [raw]
# ---
# title: 'Student dropout analysis based on previously  acquired educational achievements: A case of the University of Portalegre'
# subtitle: Business Analysis, Business Informatics Ms, Fall 2023.
# author:
#     - Izeldeen Nedal Yunis Al Fraijat
#     - Danat Semeneev
#     - Ieva Žube
#     - Pankaj Chattri
#     - Kristaps Eglītis^[Rīga Technical University]
# abstract: .
# date: last-modified
# mainfont: CMU Serif
# sansfont: CMU Serif
# monofont: CMU Serif
# fontenc: T2A
# lang: en
# keywords: AA1, AA2
# link-citations: true
# csquotes: true
# execute:
#   echo: false
#   eval: true
#   warning: false
#   error: true
#   include: true
# format:
#   pdf:
#     pdf-engine: xelatex
#     pdf-engine-opt: '-shell-escape'
#     keep-tex: true
#     cite-method: biblatex
#     header-includes:
#     - \usepackage[authordate, abbreviate = true, date = year, autocite=inline, backref = true]{biblatex-chicago}
#     - \usepackage{csquotes}
#     - \setlength{\bibhang}{0pt}
#   html:
#     html-math-method: katex
# ---

# %% [markdown]
# ## Examples

# %%
import sys 
print(sys.executable)
sys.executable

# %%
import plotly 
import plotly.io as pio
import plotly.express as px
import pandas as pd 
import numpy as np

# %%
duomenys = pd.DataFrame({'x' :  [1, 2, 3, 4 ], 'y': [1, 2, 3, 4 ]})

# %%
fig.show(renderer = 'png')

# %%
fig = px.scatter(data_frame=duomenys, x='x', y='y' )
# fig.show(renderer='vscode')
